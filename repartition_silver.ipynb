# %%
import pandas as pd
from pathlib import Path
import janitor
import re

bronze_dir = Path('DATABASES/france_172074/DATA/BRONZE')
silver_dir = Path('DATABASES/france_172074/DATA/SILVER')

# %%
df_repartition = pd.read_csv(silver_dir / 'repartition_sheet.csv', dtype=str)
df_repartition
# Out:
#          owner                          spv                        project  \
# 0    STATKRAFT         EOLIENNES SUROIT SNC                     Lanrivoaré
# 1    STATKRAFT         EOLIENNES SUROIT SNC               Méligny-le-Grand
# 2    STATKRAFT         EOLIENNES SUROIT SNC                Ménil-la-Horgne
# 3    STATKRAFT         EOLIENNES SUROIT SNC                    Roudouallec
# 4        LANÉA                   ENERGIE 02                       Dizy/Obi
# 5        LANÉA                   ENERGIE 06                      Saisseval
# 6        LANÉA  ENERGIE 21 POITOU-CHARENTES                          MLHCP
# 7        LANÉA             ENERGIE DE L'OBI                   Parc M (Obi)
# 8        LANÉA                 ENERGIE DIZY                       Dizy/Obi
# 9        LANÉA        ENERGIE DU BLANC MONT                     Blanc-Mont
# 10       LANÉA          ENERGIE LES TRENTES                    Les Trentes
# ...

# %%
df_wf = pd.read_csv(Path('DATABASES/france_172074/DATA/SILVER') / 'database_sheet.csv') 
df_wf
# Out:
#                             spv                              project  \
# 0                Energie Vendee                                Auzay
# 1         Energie Du Blanc Mont                           Blanc Mont
# 2               Energies Bocage                               Bocage
# 3           Energie Boule Bleue                          Boule Bleue
# 4             Bouresse Energies                            Bouresse
# 5                    Energie 03                           Champcourt
# 6       Energie Château Garnier                      Château Garnier
# 7               Chauve Energies                              Chauvé
# 8               Eoliennes Chouy       Chouy (Wpd Energie 21 Se N°16)
# 9       Wpd Ii Poitou Charentes                Clussais La Pommeraie
# 10               Energie 08 Sas                                Dechy
# 11                 Energie Dizy                                 Dizy
# 12                   Energie 02                            Dizy/ Obi
# ...
